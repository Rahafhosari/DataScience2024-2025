# %% [markdown]
# <a href="https://colab.research.google.com/github/Rahafhosari/DataScience2024-2025/blob/master/feature_engineering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
pd.set_option('display.max_columns',200)
pd.set_option("display.max_info_rows", 800)
pd.set_option('display.max_info_columns',800)
from sklearn import set_config
set_config(transform_output='pandas')

# %%
path = '/content/drive/MyDrive/AXSOSACADEMY/05-IntermediateML/Week17/FeatureEngineering/bikeshare_train - bikeshare_train.csv'
df = pd.read_csv(path)
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 0:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 1:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 2:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 3:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 4:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   datetime    object
#  1   season      int64
#  2   holiday     int64
#  3   workingday  int64
#  4   weather     int64
#  5   temp        float64
#  6   atemp       float64
#  7   humidity    int64
#  8   windspeed   float64
#  9   casual      int64
#  10  registered  int64
#  11  count       int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB

# %% [markdown]
# drop 2 columns

# %%
df.drop(columns=['casual','registered'])
# Out:
#                   datetime  season  holiday  workingday  weather   temp  \
# 0       2011-01-01 0:00:00       1        0           0        1   9.84
# 1       2011-01-01 1:00:00       1        0           0        1   9.02
# 2       2011-01-01 2:00:00       1        0           0        1   9.02
# 3       2011-01-01 3:00:00       1        0           0        1   9.84
# 4       2011-01-01 4:00:00       1        0           0        1   9.84
# ...                    ...     ...      ...         ...      ...    ...
# 10881  2012-12-19 19:00:00       4        0           1        1  15.58
# 10882  2012-12-19 20:00:00       4        0           1        1  14.76
# 10883  2012-12-19 21:00:00       4        0           1        1  13.94
# 10884  2012-12-19 22:00:00       4        0           1        1  13.94
# 10885  2012-12-19 23:00:00       4        0           1        1  13.12
#
#         atemp  humidity  windspeed  count
# 0      14.395        81     0.0000     16
# ...

# %% [markdown]
# #month

# %%
from datetime import datetime

df['datetime']=pd.to_datetime(df['datetime'])

# %%
df['name of month'] = df['datetime'].dt.month_name()
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count name of month
# 0        81        0.0       3          13     16       January
# 1        80        0.0       8          32     40       January
# 2        80        0.0       5          27     32       January
# 3        75        0.0       3          10     13       January
# 4        75        0.0       0           1      1       January

# %%
# df['day of month']=df['datetime'].dt.day
df['day of week (name)'] = df['datetime'].dt.day_name()
# df['hour']=df['datetime'].dt.hour
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count name of month  \
# 0        81        0.0       3          13     16       January
# 1        80        0.0       8          32     40       January
# 2        80        0.0       5          27     32       January
# 3        75        0.0       3          10     13       January
# 4        75        0.0       0           1      1       January
#
#   day of week (name)
# 0           Saturday
# 1           Saturday
# 2           Saturday
# 3           Saturday
# 4           Saturday

# %%
df['hour']=df['datetime'].dt.hour
df.head()
# Out:
#              datetime  season  holiday  workingday  weather  temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1 2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2 2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3 2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4 2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count name of month  \
# 0        81        0.0       3          13     16       January
# 1        80        0.0       8          32     40       January
# 2        80        0.0       5          27     32       January
# 3        75        0.0       3          10     13       January
# 4        75        0.0       0           1      1       January
#
#   day of week (name)  hour
# 0           Saturday     0
# 1           Saturday     1
# 2           Saturday     2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 15 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   datetime            datetime64[ns]
#  1   season              int64
#  2   holiday             int64
#  3   workingday          int64
#  4   weather             int64
#  5   temp                float64
#  6   atemp               float64
#  7   humidity            int64
#  8   windspeed           float64
#  9   casual              int64
#  10  registered          int64
#  11  count               int64
#  12  name of month       object
#  13  day of week (name)  object
#  14  hour                int32
# dtypes: datetime64[ns](1), float64(3), int32(1), int64(8), object(2)
# memory usage: 1.2+ MB

# %%
df.drop(columns=['season','datetime'])
# Out:
#        holiday  workingday  weather   temp   atemp  humidity  windspeed  \
# 0            0           0        1   9.84  14.395        81     0.0000
# 1            0           0        1   9.02  13.635        80     0.0000
# 2            0           0        1   9.02  13.635        80     0.0000
# 3            0           0        1   9.84  14.395        75     0.0000
# 4            0           0        1   9.84  14.395        75     0.0000
# ...        ...         ...      ...    ...     ...       ...        ...
# 10881        0           1        1  15.58  19.695        50    26.0027
# 10882        0           1        1  14.76  17.425        57    15.0013
# 10883        0           1        1  13.94  15.910        61    15.0013
# 10884        0           1        1  13.94  17.425        61     6.0032
# 10885        0           1        1  13.12  16.665        66     8.9981
#
#        casual  registered  count name of month day of week (name)  hour
# ...

# %% [markdown]
# Convert Temp
# The temperatures in the 'temp' and 'atemp' columns are in Celsius. Use `.apply()` and a Lambda function to convert them to Fahrenheit.

# %%
df['temp']=df['temp'].apply(lambda x: (x*9/5)+32)
df['atemp']=df['atemp'].apply(lambda x: (x*9/5)+32)

# %%
df.head()
# Out:
#              datetime  season  holiday  workingday  weather    temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  49.712  57.911
# 1 2011-01-01 01:00:00       1        0           0        1  48.236  56.543
# 2 2011-01-01 02:00:00       1        0           0        1  48.236  56.543
# 3 2011-01-01 03:00:00       1        0           0        1  49.712  57.911
# 4 2011-01-01 04:00:00       1        0           0        1  49.712  57.911
#
#    humidity  windspeed  casual  registered  count name of month  \
# 0        81        0.0       3          13     16       January
# 1        80        0.0       8          32     40       January
# 2        80        0.0       5          27     32       January
# 3        75        0.0       3          10     13       January
# 4        75        0.0       0           1      1       January
#
#   day of week (name)  hour
# 0           Saturday     0
# 1           Saturday     1
# 2           Saturday     2
# ...

# %% [markdown]
# Create a new column, 'temp_variance,' which shows how much warmer or colder the current temperature ('temp') is than the average temperate for that day of the year ('atemp'). If the current temperature is warmer than average ('atemp'), the value in 'temp_variance' should be positive.
# Drop the 'atemp' column.

# %%
df['temp_variance'] = df['temp'] - df['atemp']
df.drop(columns=['atemp'])
# Out:
#                  datetime  season  holiday  workingday  weather    temp  \
# 0     2011-01-01 00:00:00       1        0           0        1  49.712
# 1     2011-01-01 01:00:00       1        0           0        1  48.236
# 2     2011-01-01 02:00:00       1        0           0        1  48.236
# 3     2011-01-01 03:00:00       1        0           0        1  49.712
# 4     2011-01-01 04:00:00       1        0           0        1  49.712
# ...                   ...     ...      ...         ...      ...     ...
# 10881 2012-12-19 19:00:00       4        0           1        1  60.044
# 10882 2012-12-19 20:00:00       4        0           1        1  58.568
# 10883 2012-12-19 21:00:00       4        0           1        1  57.092
# 10884 2012-12-19 22:00:00       4        0           1        1  57.092
# 10885 2012-12-19 23:00:00       4        0           1        1  55.616
#
#        humidity  windspeed  casual  registered  count name of month  \
# ...

# %%
## covert values in temp variance to 'colder' or 'warmer'
df['temp_variance'] = df['temp_variance'].apply(lambda x: 'colder' if x < 0 else 'warmer')

# %%
df.head()
# Out:
#              datetime  season  holiday  workingday  weather    temp   atemp  \
# 0 2011-01-01 00:00:00       1        0           0        1  49.712  57.911
# 1 2011-01-01 01:00:00       1        0           0        1  48.236  56.543
# 2 2011-01-01 02:00:00       1        0           0        1  48.236  56.543
# 3 2011-01-01 03:00:00       1        0           0        1  49.712  57.911
# 4 2011-01-01 04:00:00       1        0           0        1  49.712  57.911
#
#    humidity  windspeed  casual  registered  count name of month  \
# 0        81        0.0       3          13     16       January
# 1        80        0.0       8          32     40       January
# 2        80        0.0       5          27     32       January
# 3        75        0.0       3          10     13       January
# 4        75        0.0       0           1      1       January
#
#   day of week (name)  hour temp_variance
# 0           Saturday     0        colder
# ...
